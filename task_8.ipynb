# %% [markdown]
# 1. Создать класс Person с полями name (имя), health (здоровье), speed (скорость), attack (атака), defense (защита), agility (ловкость) и critical_chance (шанс на критический удар).
# 2. Создать конструктор класса и методы, регулирующие процессы нанесения/получения урона (apply_damage), возникновения критической атаки (critical_hit) и уклонения (dodging_an_attack).
# 3. Создать функцию battle (не метод класса, просто функцию), принимающую два объекта Person и возвращающую объект Person, который побеждает в битве, в том состоянии, в котором он после нее остался.
#
# Правила битвы:
# Персонажи атакуют по очереди, первым атакует персонаж с наибольшей скоростью.
# Если она одинакова – тот, кто был первым в списке аргументов.
#
# Когда один персонаж атакует, здоровье атакуемого персонажа уменьшается на (показатель атаки атакующего – показатель защиты атакуемого), вплоть до нуля. Здоровье персонажа увеличиваться (регенерация) **НЕ МОЖЕТ**.
#
# Каждый персонаж имеет шанс уклонения от удара, равный значению показателя agility (от 0 до 100%). Уклонение от удара приводит к полному игнорированию урона, т.е. персонаж не получает урон вообще.
#
# Каждый персонаж имеет шанс нанести критический удар, равный значению показателя critical_chance (от 0 до 100%). Критический удар удваивает финальное значение нанесенного урона.
#
# Когда здоровье одного из участников становится <= 0, он выбывает из битвы, а его оппонент провозглашается победителем битвы.
#
# **Формальная задача:**
#
# Провести 100 боев между персонажами с одинаковыми параметрами здоровья (10), атаки (2), защиты (1), скорости (1), но разным критическим шансом (50 и 0) и уклонением (0 и 50). Т.е. сильный + непоротливый и слабый + ловкий.
#
# Вывести количество побед каждого персонажа и имя персонажа с наибольшим количеством побед в следующей форме:
#
#
# ```
# Имя_персонажа_1 - побед 53
# Имя_персонажа_2 - побед 47
#
# Наибольшее количество побед у персонажа с именем Имя_персонажа
# ```

# %%
class Person:
  pass

def battle():
  pass
