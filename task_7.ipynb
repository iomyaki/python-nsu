# %% [markdown]
# Дан sequences_7.1.xlsx файл, содержащий две колонки – номер нуклеотидной последовательности и саму последовательность. Все последовательности равной длины. Требуется:
#
# 1. Считать данные из файла с помощью pandas
#
# 2. записать в DataFrame.
# Определить консенсусную последовательность.
# 3. Посчитать и добавить в исходный DataFrame три колонки, где для каждой строки (т.е. для каждой последовательности) в этих колонках отражено посимвольное расстояние между последовательностью из строки и консенсусной последовательностью, которую Вы рассчитываете. Вычисляется как:
#
# * Доля несовпадающих элементов
# * Расстояние Джукса-Кантора
# * Расстояние Кимуры
#
# 4. Построить violin plot, где: 1) По оси абсцисс две категории – a) данные, для которых определены все три расстояния b) данные, как минимум одно из расстояний у которых не определено. 2) По оси ординат посимвольное различие (оно определено всегда)
#
# * - Под консенсусной подразумевается последовательность, на каждой позиции которой наиболее часто встречающийся элемент. Но, если таких элементов несколько в своей позиции, в данной задаче будем ставить любой из них. Т.е., исходный четырехбуквенный алфавит сохраняется.
# * - Расстояние Джукса-Кантора и Кимуры могут быть не определены, если степень различимости последовательностей слишком высока. В таком случае, целесообразно присвоить ему значение nan.
#
# Далее дан файл taxas_7.1.csv, в котором три колонки: номер, таксон и клеточная линия. Необходимо совместить получившуюся на прошлых пунктах таблицу с таблицей taxas_7.1.csv по номеру, удалить все строки, в которых клеточная линия неопределена и построить bar-plot с частотой таксонов в таблице.
#
# Получившуются таблицу назвать merged_7.1.tsv и вывести в формате tsv (не .xlsx и не .csv).

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
from google.colab import drive

drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive
