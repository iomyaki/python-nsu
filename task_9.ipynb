# %% [markdown]
# Создать две функции parsing_gene и parsing_ortho, каждая из которых парсит определенную страничку БД KEGG и выводит статистику по данному гену.
#
# Функция parsing_gene принимает несколько аргументов:
# * gene_number - номер (идентификатор) исследуемого гена в БД
# * taxa - таксономичесий идентификатор в запросе
# * остальные параметры (например, для попыток "открытия" html-странички) по желанию
#
# Функция parsing_gene "открывает" html-код странички БД KEGG и возвращает следующую информацию:
# 1. Из графы Network все фенотипы (болезни) и добавляет их в словарь в виде идентификатор - болезнь
# 2. Нуклеотидную последовательность гена
# 3. Аминокислотную последовательность гена
# 4. Позиции в геноме - переконвертировать информацию странички в следующий вид:
# ```
# chr17:16380779-16382745
# ```
#
# Функция parsing_ortho принимает те же аргументы, что и функция parsing_gene, но возвращает уже другую информацию - она считывает список ортологов и значения параметров Identity и SW-Score и коэффициент корреляции Пирсона между этими данными. Коэффициент корреляции считается для первых 10, 100, 200 и 500 ортологов. Если ортологов меньше одного из заявленных выше чисел (например, 354 ортолога), то считается максимально возможные значения из списка 10, 100, 200, 500 и максимально возможное значение ортологов со странички БД. Т.е. если ортологов 354, то считается корреляция для 10, 100, 200 и 354 ортологов.
#
# Данная функция должна возвращать информацию в следующем виде:
# ```
# 10 orthologs - значение корреляции Пирсона
# 100 orthologs - значение корреляции Пирсона
# и т.д.
# ```
#
# Реализовать необходимо все на следующих аргументах:
#
# taxa = 'hsa' (общий для двух функций)
#
# gene_number = 7314 (общий для двух функций)
#
# Конкретные адреса для БД KEGG, по которым нужно получить всю эту информацию, приведены в нижнем блоке кода:

# %% [markdown]
# https://www.kegg.jp/entry/hsa:7314
#
# https://www.kegg.jp/ssdb-bin/ssdb_best?org_gene=hsa:7314

# %%
def parsing_gene(taxa, gene_number):
  # https://www.kegg.jp/entry/ и далее передается информация в следующем виде - taxa:gene_number, где taxa - hsa, а gene_number - 7314
  return

def parsing_ortho(taxa, gene_number):
  # https://www.kegg.jp/ssdb-bin/ssdb_best?org_gene= и далее передается информация в следующем виде - taxa:gene_number, где taxa - hsa, а gene_number - 7314
  return
