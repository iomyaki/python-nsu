# %% [markdown]
# # **ФИО:**
# # **ГРУППА:**

# %% [markdown]
# Написать программу, которая принимает на вход последовательность нуклеотидов
#
# и выявляет мобильный генетический элемент GAGAGACA. Если мобильный генетический
#
# элемент имеет место быть, то определить его начальную позицию и
#
#  замаскировать его (сделать в нижнем регистре).
#
#  Вывести ответ в следующем формате:
#
#  В нуклеотидной строке:
#
#  ATGCCGTACACAGTGAGAGACATATG
#
#  имеется мобильный генетический элемент в следующей позиции:
#
#  15
#
#  или
#
#  не имеется мобильный генетчиеский элемент

# %%
test_str = 'ATGCCGTACACAGTGAGAGACATATG'
mob_el = 'GAGAGACA'

# %% [markdown]
# Паша очень любит кататься на общественном транспорте, а получая билет, сразу проверяет, счастливый ли ему попался. Билет считается счастливым, если сумма первых трех цифр совпадает с суммой последних трех цифр номера билета.
#
# Однако Паша очень плохо считает в уме, поэтому попросил вас написать программу, которая проверит равенство сумм и выведет "Счастливый", если суммы совпадают, и "Обычный", если суммы различны.
#
# На вход программе подаётся строка из шести цифр.
#
# Выводить нужно только слово "Счастливый" или "Обычный", с большой буквы.

# %% [markdown]
# На вход подается список нуклеотидов ДНК.
#
# Необходимо добавить в начало списка три элемента - нуклеотида: А T G
#
# Последние три элемента последовательности заменить на любой стоп-кодон.
#
# Последовательность вывести в формате строки и определить общую длину последовательности
#
# с учетом старт- и стоп-кодонов.

# %%
nucl_list = [i for i in input()]

# %% [markdown]
# У вас есть словарь, в котором содержится количество аминокислот в последвоателньости.
#
# Необходимо реализовать следующее:
#
# * Если триптофанов больше тирозинов, то добавить еще два лизина;
#
# * Если валинов меньше изолейцинов и лейцинов в сумме, то убрать валины;
#
# * Если серин только один, то выпить (зачеркнуто) добавить столько глицинов,
#
# сколько в сумме аминокислот;
#
# * Заменить лизин на аргинин.

# %%
aa_dict = {'Trp': 5, 'Asn': 3,
           'Lys': 1, 'Leu': 2,
           'Ile': 9, 'Val': 10,
           'Ser': 1, 'Tyr': 2}
